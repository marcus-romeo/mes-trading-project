# %% [markdown]
# # MES Futures Project — Environment Test
#
# ## Purpose
#
# This notebook verifies that the MES futures project is running in the correct Python environment and that the core packages needed for the project are installed and working.
#
# The project uses a dedicated virtual environment (`.venv`) so its Python version and package dependencies remain isolated from other projects, including the Olist analytics project.
#
# ### Environment
# - Python 3.12
# - JupyterLab
# - Dedicated kernel: `Python 3.12 (MES Trading)`
#
# ### Core Packages
# - `pandas` — data manipulation and analysis
# - `databento` — historical MES futures market data
# - `SQLAlchemy` — connection between Python and PostgreSQL
# - `psycopg2` — PostgreSQL database driver
# - `python-dotenv` — securely loads configuration values such as API credentials from a `.env` file

# %%
# Verify that this notebook is running inside the dedicated MES project environment.
# This checks the Python version, the exact Python executable being used,
# and the versions of the main packages we will rely on throughout the project.

import sys
import pandas as pd
import sqlalchemy
import databento as db

print("Python version:", sys.version)
print("Python executable:", sys.executable)
print("pandas version:", pd.__version__)
print("SQLAlchemy version:", sqlalchemy.__version__)
print("Databento version:", db.__version__)
# Out:
# Python version: 3.12.10 (v3.12.10:0cc81280367, Apr  8 2025, 08:47:00) [Clang 13.0.0 (clang-1300.0.29.30)]
# Python executable: /Users/marcusromeo/Desktop/mes-trading-project/.venv/bin/python
# pandas version: 3.0.5
# SQLAlchemy version: 2.0.52
# Databento version: 0.86.0
